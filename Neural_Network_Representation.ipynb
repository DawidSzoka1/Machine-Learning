# %% [markdown]
# <a href="https://colab.research.google.com/github/DawidSzoka1/machine-learning/blob/main/Neural_Network_Representation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Zdjecia z kursu**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
A = np.random.randn(4,3)

B = np.sum(A, axis = 1, keepdims = True)
B.shape
# Out:
# (4, 1)
