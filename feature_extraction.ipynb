# %% [markdown]
# <a href="https://colab.research.google.com/github/DawidSzoka1/machine-learning/blob/main/feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#               Open    High       Low   Close    Volume
# Date
# 2024-07-18  189.59  189.68  181.4480  183.75  51043626
# 2024-07-17  191.35  191.58  185.9900  187.93  48076139
# 2024-07-16  195.59  196.62  192.2400  193.02  33994714
# 2024-07-15  194.56  196.19  190.8300  192.72  40683227
# 2024-07-12  194.80  196.47  193.8301  194.49  30598525

# %%
df = df_raw[:5].copy()
df
# Out:
#               Open    High       Low   Close    Volume
# Date
# 2024-07-18  189.59  189.68  181.4480  183.75  51043626
# 2024-07-17  191.35  191.58  185.9900  187.93  48076139
# 2024-07-16  195.59  196.62  192.2400  193.02  33994714
# 2024-07-15  194.56  196.19  190.8300  192.72  40683227
# 2024-07-12  194.80  196.47  193.8301  194.49  30598525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2024-07-18 to 2024-07-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open    High       Low   Close    Volume        day  month  year
# Date
# 2024-07-18  189.59  189.68  181.4480  183.75  51043626   Thursday      7  2024
# 2024-07-17  191.35  191.58  185.9900  187.93  48076139  Wednesday      7  2024
# 2024-07-16  195.59  196.62  192.2400  193.02  33994714    Tuesday      7  2024
# 2024-07-15  194.56  196.19  190.8300  192.72  40683227     Monday      7  2024
# 2024-07-12  194.80  196.47  193.8301  194.49  30598525     Friday      7  2024

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_high
# 0   175.0          False        False
# 1   178.5           True        False
# 2   185.0          False         True
# 3   191.0          False         True
# 4   184.5          False         True
# 5   183.0          False         True
# 6   168.0          False        False

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['pl_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  pl_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df['extansion'] = df['website'].apply(lambda x: x.split('.')[1])
df
# Out:
#       website extansion
# 0       wp.pl        pl
# 1     onet.pl        pl
# 2  google.com       com

# %%
new = df.website.str.split('.', expand=True)
print(new)
df['portal'] = new[0]
df['extansion'] = new[1]
df
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com
#       website extansion  portal
# 0       wp.pl        pl      wp
# 1     onet.pl        pl    onet
# 2  google.com       com  google
